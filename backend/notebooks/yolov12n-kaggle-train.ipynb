# %%
#Install and Import Library
# %pip install ultralytics
import ultralytics
ultralytics.checks()

# %%
#Set Logger is TensorBoard or Comet
logger = 'TensorBoard'

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .

# %%
#Train models with YOLOv12 Nano
# !yolo train model=yolo12n.pt \
data='kaggle/input/vietnameses-tomato-disease-dataset/Tomato-Disease-Dataset/data.yaml' \
epochs=200 imgsz=640 batch=64 pretrained=False \
degrees=10 translate=0.1 scale=0.5 shear=2.0 perspective=0.001 \
flipud=0.2 fliplr=0.5 mosaic=0.8 mixup=0.2 copy_paste=0.2 \
hsv_h=0.015 hsv_s=0.7 hsv_v=0.5

# %%
#Download the model has been trained
import shutil

shutil.make_archive('/kaggle/working/run/detect/train', 'zip', '/kaggle/working/train')
