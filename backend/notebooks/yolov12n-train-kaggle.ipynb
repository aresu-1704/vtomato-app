# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6281.6/8062.4 GB disk)

# %%
from ultralytics import YOLO
import multiprocessing

def main():
    model = YOLO("yolo12n.pt")
    model.train(
        data='/kaggle/input/vietnameses-tomato-disease-dataset/Tomato-Disease-Dataset/data.yaml',
        epochs=200,
        imgsz=640,
        batch=64,
        pretrained=False,
        device="cuda",
        verbose=True,
        plots=True,
        
        #Tăng cường
        degrees=10,
        translate=0.1,
        scale=0.5,
        shear=2.0,
        perspective=0.001,
        flipud=0.2,
        fliplr=0.5,
        mosaic=0.8,
        mixup=0.2,
        copy_paste=0.2,
        hsv_h=0.015,
        hsv_s=0.7,
        hsv_v=0.5
    )

if __name__ == '__main__':
    multiprocessing.freeze_support()
    main()
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/input/yolov12n/pytorch/models/1/best.pt")
model.to('cuda')

data_yaml = "/kaggle/input/tomato-leaf-diseases-dataset-for-object-detection/Tomato leaf diseases dataset for Object Detection/Dataset with augmentation/data.yaml"

if __name__ == '__main__':
    metrics = model.val(data=data_yaml, split='train', save_json=True)

    # In kết quả
    print("\n===== Evaluation Metrics =====")
    print(f"Precision (P):     {metrics.box.p.mean()*100:.4f}")
    print(f"Recall (R):        {metrics.box.r.mean()*100:.4f}")
    print(f"F1-score:          {metrics.box.f1.mean()*100:.4f}")
    print(f"mAP@0.5:           {metrics.box.map50.mean()*100:.4f}")
    print(f"mAP@0.5:0.95:      {metrics.box.map.mean()*100:.4f}")
    print("==============================")
# Out:
# YOLOv12n summary (fused): 159 layers, 2,558,483 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.2 ms, read: 15.3±8.0 MB/s, size: 51.1 KB)
# val: Scanning /kaggle/input/tomato-leaf-diseases-dataset-for-object-detection/Tomato leaf diseases dataset for Object Detection/Dataset with augmentation/train/labels... 9730 images, 0 backgrounds, 0 corrupt: 100%|██████████| 9730/9730 [00:26<00:00, 369.92it/s]
# WARNING ⚠️ val: Cache directory /kaggle/input/tomato-leaf-diseases-dataset-for-object-detection/Tomato leaf diseases dataset for Object Detection/Dataset with augmentation/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 609/609 [01:20<00:00,  7.60it/s]
#                    all       9730      35308       0.93      0.916      0.963      0.857
#           Early Blight       2183       3245      0.871      0.916      0.954      0.862
# ...

# %%
# !zip -r /kaggle/working/train.zip /kaggle/working/runs/detect/train
# Out:
#   adding: kaggle/working/runs/detect/train2/ (stored 0%)
#   adding: kaggle/working/runs/detect/train2/F1_curve.png (deflated 7%)
#   adding: kaggle/working/runs/detect/train2/train_batch1.jpg (deflated 2%)
#   adding: kaggle/working/runs/detect/train2/val_batch2_pred.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train2/confusion_matrix.png (deflated 22%)
#   adding: kaggle/working/runs/detect/train2/train_batch2.jpg (deflated 1%)
#   adding: kaggle/working/runs/detect/train2/PR_curve.png (deflated 12%)
#   adding: kaggle/working/runs/detect/train2/train_batch9312.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train2/results.csv (deflated 63%)
#   adding: kaggle/working/runs/detect/train2/labels.jpg (deflated 25%)
#   adding: kaggle/working/runs/detect/train2/train_batch9311.jpg (deflated 5%)
#   adding: kaggle/working/runs/detect/train2/results.png (deflated 8%)
#   adding: kaggle/working/runs/detect/train2/labels_correlogram.jpg (deflated 40%)
# ...
